# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import requests
import urllib

# %%
os.chdir("C:/Users/momaleki/Desktop/Project")
os.getcwd()
# Out:
# 'C:\\Users\\momaleki\\Desktop\\Project'

# %%
COVID_Hospitals= pd.read_csv("Data/COVID_Data/data/context_hospitals_covidcaremap-2021-05-29.csv")

# %%
df = COVID_Hospitals
df.head()
# Out:
#                                                Name       Hospital Type  \
# 0                     IU HEALTH UNIVERSITY HOSPITAL  GENERAL ACUTE CARE
# 1  HEALTHSOUTH NEW ENGLAND REHABILIATION AT BEVERLY      REHABILITATION
# 2                             ST. JOSEPH'S HOSPITAL     CRITICAL ACCESS
# 3                          HOSP SAN CARLOS BORROMEO  GENERAL ACUTE CARE
# 4                          RIVERVIEW MEDICAL CENTER  GENERAL ACUTE CARE
#
#                                 Address Address_2          City State  \
# 0                   550 UNIVERSITY BLVD       NaN  INDIANAPOLIS    IN
# 1  800 CUMMINGS CENTER, 1ST FL, UNIT147       NaN       BEVERLY    MA
# 2                  12886 TROXLER AVENUE       NaN      HIGHLAND    IL
# 3             550 CONCEPCION VERA AYALA       NaN          MOCA    PR
# 4                     1 RIVERVIEW PLAZA       NaN      RED BANK    NJ
#
#    Zipcode    County  Latitude  Longitude  ...  ICU Bed Occupancy Rate  \
# 0    46202    MARION  39.77528  -86.17656  ...                     NaN
# 1     1915     ESSEX  42.56099  -70.88724  ...                     NaN
# 2    62249   MADISON  38.75458  -89.66760  ...                     NaN
# 3      676      MOCA  18.39019  -67.10997  ...                    0.73
# 4     7701  MONMOUTH  40.35398  -74.06384  ...                    0.42
#
#    Staffed All Beds - SOURCE     Staffed ICU Beds - SOURCE  \
# 0                       None                          None
# 1                       None                          None
# 2                       None                          None
# 3   HCRIS-Total Staffed Beds  HCRIS-ICU Total Staffed Beds
# 4   HCRIS-Total Staffed Beds  HCRIS-ICU Total Staffed Beds
#
#    Licensed All Beds - SOURCE  All Bed Occupancy Rate - SOURCE  \
# 0                         NaN                             None
# 1                  HIFLD-BEDS                             None
# 2                         NaN                             None
# 3               DH-NUM_LICENS   HCRIS-Total Bed Occupancy Rate
# 4               DH-NUM_LICENS   HCRIS-Total Bed Occupancy Rate
#
#   ICU Bed Occupancy Rate - SOURCE     CCM_ID   DH-ID  HCRIS-ID     HIFLD-ID
# 0                            None        100     NaN       NaN        100.0
# 1                            None   10001915     NaN       NaN   10001915.0
# 2                            None  100062249     NaN       NaN  100062249.0
# 3        HCRIS-ICU Occupancy Rate    1000676  4294.0  400111.0    1000676.0
# 4        HCRIS-ICU Occupancy Rate   10007701  2512.0  310034.0   10007701.0
#
# [5 rows x 24 columns]

# %%
df['FIPS'] = df['Name']

start = 0
end = df.shape[0]//5
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']
    
start = df.shape[0]//5
end = (df.shape[0]//5) * 2
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']

start = (df.shape[0]//5) * 2
end = (df.shape[0]//5) * 3
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']
    
start = (df.shape[0]//5) * 3
end = (df.shape[0]//5) * 4
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']
    
    
start = (df.shape[0]//5) * 4
end = (df.shape[0]//5) * 5
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']    
    
    
start = (df.shape[0]//5) * 5
end = df.shape[0] 
for i in range(start, end):
    params = []
    url = []
    response = []
    params = urllib.parse.urlencode({'latitude': df['Latitude'].iloc[i,], 'longitude': df['Longitude'].iloc[i,], 'format':'json'})
    url = 'https://geo.fcc.gov/api/census/block/find?'  + params 
    response =  requests.get(url)
    data = response.json()
    df['FIPS'].iloc[i,] = data['County']['FIPS']
# Out:
# C:\Users\momaleki\Anaconda3\lib\site-packages\pandas\core\indexing.py:1783: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
df['FIPS'].tail()
# Out:
# 7149    12011
# 7150    12033
# 7151    12069
# 7152    12121
# 7153    12127
# Name: FIPS, dtype: object

# %%
df.to_csv('COVID_Hospitals_PYTHON.csv')
